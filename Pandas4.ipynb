# %% [markdown]
# <a href="https://colab.research.google.com/github/shivraj7/scalar/blob/main/Pandas4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Agenda
#
#
#
# *   Insights on IMDB data
# *   Melting and pivoting in Pandas

# %%
import numpy as np
import pandas as pd

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 69.7MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 42.5MB/s]

# %%
movies = pd.read_csv('movies.csv', index_col=0)
directors = pd.read_csv('directors.csv',index_col=0)

# %%
data = pd.merge(movies, directors, left_on = 'director_id', right_on = 'id',how = 'left')

# %%
data.drop(columns = ['director_id', 'id_y'], inplace = True)

# %%
#Most productive director
#Most risky movies
#High budget director.......

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %% [markdown]
# #High budget director movies

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
#find the details of movies by high budget directors
#high budget = at least 1 movie with budget > 100M

# %%
data['budget'] > 100000000
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: budget, Length: 1465, dtype: bool

# %%
data[data['budget'] > 100000000]
# Out:
#       id_x     budget  popularity     revenue  \
# 0    43597  237000000         150  2787965087
# 1    43598  300000000         139   961000000
# 2    43599  245000000         107   880674609
# 3    43600  250000000         112  1084939099
# 4    43602  258000000         115   890871626
# ..     ...        ...         ...         ...
# 185  43897  105000000          58   121214377
# 186  43898  102000000          73   130482868
# 201  43929  115000000          41   274703340
# 290  44088  130000000          50   117831631
# 328  44162  150000000          47   919838758
#
#                                         title  vote_average  vote_count  year  \
# 0                                      Avatar           7.2       11800  2009
# 1    Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                     Spectre           6.3        4466  2015
# 3                       The Dark Knight Rises           7.6        9106  2012
# ...

# %%
director_max_budget = data.groupby(by ='director_name')['budget'].max()
director_max_budget
# Out:
# director_name
# Adam McKay                     100000000
# Adam Shankman                   80000000
# Alejandro González Iñárritu    135000000
# Alex Proyas                    140000000
# Alexander Payne                 30000000
#                                  ...
# Wes Craven                      40000000
# Wolfgang Petersen              175000000
# Woody Allen                     30000000
# Zack Snyder                    250000000
# Zhang Yimou                     94000000
# Name: budget, Length: 199, dtype: int64

# %%
director_max_budget[director_max_budget>100000000]
# Out:
# director_name
# Alejandro González Iñárritu    135000000
# Alex Proyas                    140000000
# Andrew Adamson                 225000000
# Ang Lee                        137000000
# Barry Sonnenfeld               225000000
#                                  ...
# Tim Story                      130000000
# Tom Shadyac                    175000000
# Tom Tykwer                     102000000
# Wolfgang Petersen              175000000
# Zack Snyder                    250000000
# Name: budget, Length: 79, dtype: int64

# %%
#storing directors name
names = director_max_budget[director_max_budget>100000000].index
names
# Out:
# Index(['Alejandro González Iñárritu', 'Alex Proyas', 'Andrew Adamson',
#        'Ang Lee', 'Barry Sonnenfeld', 'Bill Condon', 'Brett Ratner',
#        'Bryan Singer', 'Chris Columbus', 'Chris Weitz', 'Christopher Nolan',
#        'Darren Aronofsky', 'David Ayer', 'David Fincher', 'Doug Liman',
#        'Edward Zwick', 'Francis Lawrence', 'Frank Coraci', 'George Miller',
#        'Gore Verbinski', 'Guillermo del Toro', 'Guy Ritchie', 'James Cameron',
#        'James Mangold', 'James Wan', 'Jan de Bont', 'Joe Wright',
#        'Joel Schumacher', 'John McTiernan', 'John Woo', 'Jon Favreau',
#        'Jon M. Chu', 'Jon Turteltaub', 'Jonathan Liebesman', 'Justin Lin',
#        'Kenneth Branagh', 'Kevin Reynolds', 'Lee Tamahori', 'Lilly Wachowski',
#        'Louis Leterrier', 'M. Night Shyamalan', 'Marc Forster',
#        'Martin Campbell', 'Martin Scorsese', 'McG', 'Michael Apted',
#        'Michael Bay', 'Michael Mann', 'Mike Newell', 'Oliver Stone',
# ...

# %%
budget = director_max_budget[director_max_budget>100000000].values
budget
# Out:
# array([135000000, 140000000, 225000000, 137000000, 225000000, 120000000,
#        210000000, 270000000, 125000000, 180000000, 250000000, 125000000,
#        175000000, 150000000, 178000000, 140000000, 160000000, 110000000,
#        150000000, 300000000, 180000000, 125000000, 237000000, 120000000,
#        190000000, 160000000, 150000000, 125000000, 160000000, 125000000,
#        200000000, 130000000, 150000000, 150000000, 185000000, 150000000,
#        175000000, 140000000, 176000003, 150000000, 150000000, 200000000,
#        200000000, 170000000, 200000000, 155000000, 210000000, 107000000,
#        150000000, 155000000, 120000000, 105000000, 130000000, 209000000,
#        250000000, 110000000, 110000000, 140000000, 200000000, 145000000,
#        380000000, 145000000, 130000000, 200000000, 116000000, 200000000,
#        150000000, 245000000, 258000000, 150000000, 115000000, 110000000,
#        185000000, 200000000, 130000000, 175000000, 102000000, 175000000,
#        250000000])

# %%
(director_max_budget[director_max_budget>100000000]).reset_index()
# Out:
#                   director_name     budget
# 0   Alejandro González Iñárritu  135000000
# 1                   Alex Proyas  140000000
# 2                Andrew Adamson  225000000
# 3                       Ang Lee  137000000
# 4              Barry Sonnenfeld  225000000
# ..                          ...        ...
# 74                    Tim Story  130000000
# 75                  Tom Shadyac  175000000
# 76                   Tom Tykwer  102000000
# 77            Wolfgang Petersen  175000000
# 78                  Zack Snyder  250000000
#
# [79 rows x 2 columns]

# %%
df_budget = (director_max_budget[director_max_budget>100000000]).reset_index()
df_budget.head()
# Out:
#                  director_name     budget
# 0  Alejandro González Iñárritu  135000000
# 1                  Alex Proyas  140000000
# 2               Andrew Adamson  225000000
# 3                      Ang Lee  137000000
# 4             Barry Sonnenfeld  225000000

# %%
names = df_budget['director_name']
names
# Out:
# 0     Alejandro González Iñárritu
# 1                     Alex Proyas
# 2                  Andrew Adamson
# 3                         Ang Lee
# 4                Barry Sonnenfeld
#                  ...
# 74                      Tim Story
# 75                    Tom Shadyac
# 76                     Tom Tykwer
# 77              Wolfgang Petersen
# 78                    Zack Snyder
# Name: director_name, Length: 79, dtype: object

# %%
data['director_name'].isin(names)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1460     True
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: director_name, Length: 1465, dtype: bool

# %%
#answer for
#find the details of movies by high budget directors
#high budget = at least 1 movie with budget > 100M

data[data['director_name'].isin(names)]
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1450  48267     400000          33   100000000
# 1451  48268     200000          13     4505922
# 1452  48274          0           5     2611555
# 1458  48335      60000          27     3221152
# 1460  48363          0           3      321952
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#another method
def high_budget(g):
  return g['budget'].max() > 100000000

# %%
data.groupby('director_name').filter(high_budget)
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1450  48267     400000          33   100000000
# 1451  48268     200000          13     4505922
# 1452  48274          0           5     2611555
# 1458  48335      60000          27     3221152
# 1460  48363          0           3      321952
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
#another method using lamda function
data.groupby('director_name').filter(lambda x:x['budget'].max()>100000000)
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1450  48267     400000          33   100000000
# 1451  48268     200000          13     4505922
# 1452  48274          0           5     2611555
# 1458  48335      60000          27     3221152
# 1460  48363          0           3      321952
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %% [markdown]
# #high risk movies
# If a movie has higher budget than avg for that director

# %%
# Not covered in class, tried to solve by filter, not successed
def risky(x):
  return x['budget'].any() > x['budget'].mean()


data_risky = data.groupby('director_name').filter(risky)
data_risky
# Out:
# Empty DataFrame
# Columns: [id_x, budget, popularity, revenue, title, vote_average, vote_count, year, month, day, director_name, gender]
# Index: []

# %%
def risky(x):
  x['risky'] = x['budget'] - x['budget'].mean() > 0
  return x

data = data.groupby('director_name', group_keys=False).apply(risky)
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data[data['risky']==True]
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1319  47023    6500000          11    13368437
# 1349  47229    5000000           3     4842699
# 1356  47263   15000000          10           0
# 1361  47296   15000000          30    13060843
# 1393  47524    3000000           5           0
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['risky'].value_counts()
# Out:
# risky
# False    809
# True     656
# Name: count, dtype: int64

# %% [markdown]
# # Most Productive Director
# more work, more movies, more productive

# %%
data['director_name'].value_counts()
# Out:
# director_name
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: count, Length: 199, dtype: int64

# %%
data_agg= data.groupby('director_name').aggregate({'year':['min','max'], 'title':['count']})
data_agg
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5
# ...                           ...   ...   ...
# Wes Craven                   1984  2011    10
# Wolfgang Petersen            1981  2006     7
# Woody Allen                  1977  2013    18
# Zack Snyder                  2004  2016     7
# Zhang Yimou                  2002  2014     6
#
# [199 rows x 3 columns]

# %%
#note:- in above output, there are 2 level of indexing for col, it is called multilevel indexing
data_agg.columns
# Out:
# MultiIndex([( 'year',   'min'),
#             ( 'year',   'max'),
#             ('title', 'count')],
#            )

# %%
data_agg['year']
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
data_agg['year']['max']
# Out:
# director_name
# Adam McKay                     2015
# Adam Shankman                  2012
# Alejandro González Iñárritu    2015
# Alex Proyas                    2016
# Alexander Payne                2013
#                                ...
# Wes Craven                     2011
# Wolfgang Petersen              2006
# Woody Allen                    2013
# Zack Snyder                    2016
# Zhang Yimou                    2014
# Name: max, Length: 199, dtype: int64

# %%
data_agg[('year','max')]
# Out:
# director_name
# Adam McKay                     2015
# Adam Shankman                  2012
# Alejandro González Iñárritu    2015
# Alex Proyas                    2016
# Alexander Payne                2013
#                                ...
# Wes Craven                     2011
# Wolfgang Petersen              2006
# Woody Allen                    2013
# Zack Snyder                    2016
# Zhang Yimou                    2014
# Name: (year, max), Length: 199, dtype: int64

# %%
data_agg[('title','count')]
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: (title, count), Length: 199, dtype: int64

# %%
#multi to single level indexing
data_agg.head()
# Out:
#                              year       title
#                               min   max count
# director_name
# Adam McKay                   2004  2015     6
# Adam Shankman                2001  2012     8
# Alejandro González Iñárritu  2000  2015     6
# Alex Proyas                  1994  2016     5
# Alexander Payne              1999  2013     5

# %%
data_agg.columns=['year_min','year_max','title_count']
data_agg
# Out:
#                              year_min  year_max  title_count
# director_name
# Adam McKay                       2004      2015            6
# Adam Shankman                    2001      2012            8
# Alejandro González Iñárritu      2000      2015            6
# Alex Proyas                      1994      2016            5
# Alexander Payne                  1999      2013            5
# ...                               ...       ...          ...
# Wes Craven                       1984      2011           10
# Wolfgang Petersen                1981      2006            7
# Woody Allen                      1977      2013           18
# Zack Snyder                      2004      2016            7
# Zhang Yimou                      2002      2014            6
#
# [199 rows x 3 columns]

# %%
data_agg = data_agg.reset_index()
data_agg
# Out:
#                    director_name  year_min  year_max  title_count
# 0                     Adam McKay      2004      2015            6
# 1                  Adam Shankman      2001      2012            8
# 2    Alejandro González Iñárritu      2000      2015            6
# 3                    Alex Proyas      1994      2016            5
# 4                Alexander Payne      1999      2013            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      1984      2011           10
# 195            Wolfgang Petersen      1981      2006            7
# 196                  Woody Allen      1977      2013           18
# 197                  Zack Snyder      2004      2016            7
# 198                  Zhang Yimou      2002      2014            6
#
# [199 rows x 4 columns]

# %%
data_agg['active_year'] = data_agg['year_max']-data_agg['year_min']
data_agg
# Out:
#                    director_name  year_min  year_max  title_count  active_year
# 0                     Adam McKay      2004      2015            6           11
# 1                  Adam Shankman      2001      2012            8           11
# 2    Alejandro González Iñárritu      2000      2015            6           15
# 3                    Alex Proyas      1994      2016            5           22
# 4                Alexander Payne      1999      2013            5           14
# ..                           ...       ...       ...          ...          ...
# 194                   Wes Craven      1984      2011           10           27
# 195            Wolfgang Petersen      1981      2006            7           25
# 196                  Woody Allen      1977      2013           18           36
# 197                  Zack Snyder      2004      2016            7           12
# 198                  Zhang Yimou      2002      2014            6           12
#
# [199 rows x 5 columns]

# %%
 data_agg['movies_per_year'] = data_agg['title_count']/data_agg['active_year']
 data_agg
# Out:
#                    director_name  year_min  year_max  title_count  \
# 0                     Adam McKay      2004      2015            6
# 1                  Adam Shankman      2001      2012            8
# 2    Alejandro González Iñárritu      2000      2015            6
# 3                    Alex Proyas      1994      2016            5
# 4                Alexander Payne      1999      2013            5
# ..                           ...       ...       ...          ...
# 194                   Wes Craven      1984      2011           10
# 195            Wolfgang Petersen      1981      2006            7
# 196                  Woody Allen      1977      2013           18
# 197                  Zack Snyder      2004      2016            7
# 198                  Zhang Yimou      2002      2014            6
#
#      active_year  movies_per_year
# 0             11         0.545455
# 1             11         0.727273
# 2             15         0.400000
# ...

# %%
data_agg.sort_values(by = 'movies_per_year', ascending = False, inplace = True)
data_agg

# %%
data_agg.loc[190].values[0]
# Out:
# 'Tyler Perry'

# %%
data_agg.iloc[0].values[0]
# Out:
# 'Tyler Perry'

# %%
data_agg.head(1).values[0]
# Out:
# array(['Tyler Perry', 2006, 2013, 9, 7, 1.2857142857142858], dtype=object)

# %% [markdown]
# #working with pfizer

# %%
# !gdown 173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# To: /content/Pfizer_1.csv
# 100% 1.51k/1.51k [00:00<00:00, 7.23MB/s]

# %%
data = pd.read_csv('Pfizer_1.csv')

# %%
data
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB

# %%
data.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
data.shape
# Out:
# (18, 15)

# %%
#here cols are too much, can we increase rows and decrease cols
#melting = increase rows and decrease cols
pd.melt(data, id_vars= ['Date','Drug_Name','Parameter'])
# Out:
#            Date                Drug_Name    Parameter  variable  value
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00   23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00   12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00    NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00    NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00   24.0
# ..          ...                      ...          ...       ...    ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00   14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00   23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00   28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00   24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00   15.0
#
# [216 rows x 5 columns]

# %%
pd.melt(data, id_vars= ['Date','Drug_Name','Parameter'], var_name='time', value_name='reading')
# Out:
#            Date                Drug_Name    Parameter      time  reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
data.transpose()
# Out:
#                                 0                        1   \
# Date                    15-10-2020               15-10-2020
# Drug_Name  diltiazem hydrochloride  diltiazem hydrochloride
# Parameter              Temperature                 Pressure
# 1:30:00                       23.0                     12.0
# 2:30:00                       22.0                     13.0
# 3:30:00                        NaN                      NaN
# 4:30:00                       21.0                     11.0
# 5:30:00                       21.0                     13.0
# 6:30:00                         22                       14
# 7:30:00                       23.0                     16.0
# 8:30:00                       21.0                     16.0
# 9:30:00                       22.0                     24.0
# 10:30:00                        20                       18
# 11:30:00                      20.0                     19.0
# 12:30:00                        21                       20
#
# ...

# %%
#pivoting is opposite of melting=>increase cols and decreasing rows
data_melt = pd.melt(data, id_vars= ['Date','Drug_Name','Parameter'], var_name='time', value_name='reading')
data_melt
# Out:
#            Date                Drug_Name    Parameter      time  reading
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00     23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00     12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00      NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00      NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00     24.0
# ..          ...                      ...          ...       ...      ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00     14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00     23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00     28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00     24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
pd.pivot(data_melt, index = ['Date','Drug_Name', 'time'], columns= 'Parameter', values='reading')
# Out:
# Parameter                                    Pressure  Temperature
# Date       Drug_Name               time
# 15-10-2020 diltiazem hydrochloride 10:30:00      18.0         20.0
#                                    11:30:00      19.0         20.0
#                                    12:30:00      20.0         21.0
#                                    1:30:00       12.0         23.0
#                                    2:30:00       13.0         22.0
# ...                                               ...          ...
# 17-10-2020 ketamine hydrochloride  5:30:00       11.0         17.0
#                                    6:30:00       12.0         18.0
#                                    7:30:00       12.0         19.0
#                                    8:30:00       11.0         20.0
#                                    9:30:00       12.0         21.0
#
# [108 rows x 2 columns]

# %%
pd.pivot(data_melt, index = ['Date','Drug_Name', 'time'], columns= 'Parameter', values='reading').reset_index()
# Out:
# Parameter        Date                Drug_Name      time  Pressure  \
# 0          15-10-2020  diltiazem hydrochloride  10:30:00      18.0
# 1          15-10-2020  diltiazem hydrochloride  11:30:00      19.0
# 2          15-10-2020  diltiazem hydrochloride  12:30:00      20.0
# 3          15-10-2020  diltiazem hydrochloride   1:30:00      12.0
# 4          15-10-2020  diltiazem hydrochloride   2:30:00      13.0
# ..                ...                      ...       ...       ...
# 103        17-10-2020   ketamine hydrochloride   5:30:00      11.0
# 104        17-10-2020   ketamine hydrochloride   6:30:00      12.0
# 105        17-10-2020   ketamine hydrochloride   7:30:00      12.0
# 106        17-10-2020   ketamine hydrochloride   8:30:00      11.0
# 107        17-10-2020   ketamine hydrochloride   9:30:00      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 20.0
# 2                 21.0
# 3                 23.0
# 4                 22.0
# ...
