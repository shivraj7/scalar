# %% [markdown]
# <a href="https://colab.research.google.com/github/shivraj7/scalar/blob/main/Pandas3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Agenda
#
#
#
# *   Pandas Concat and merging
# *   Intro to IMDB usecase
# *   groupby()
# *   filter(), apply()

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Pandas Concat

# %%
# creating dataframe
users = pd.DataFrame({"userid":[1,2,3], "name":["sharad", "shahid", "khusali"]})
# Here userid and name are the col(key) and 1 sharad, 2 shahid are rows(value)
users
# Out:
#    userid     name
# 0       1   sharad
# 1       2   shahid
# 2       3  khusali

# %%
msgs = pd.DataFrame({"userid":[1,1,2,4], "msg":["hmm", "achha", "theek hai", "nice"]})
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1      achha
# 2       2  theek hai
# 3       4       nice

# %%
msgs.shape
# Out:
# (4, 2)

# %%
pd.concat([users,msgs]) #by default rowwise concat
# Out:
#    userid     name        msg
# 0       1   sharad        NaN
# 1       2   shahid        NaN
# 2       3  khusali        NaN
# 0       1      NaN        hmm
# 1       1      NaN      achha
# 2       2      NaN  theek hai
# 3       4      NaN       nice

# %%
pd.concat([users,msgs],axis=1) #colwise
# Out:
#    userid     name  userid        msg
# 0     1.0   sharad       1        hmm
# 1     2.0   shahid       1      achha
# 2     3.0  khusali       2  theek hai
# 3     NaN      NaN       4       nice

# %% [markdown]
# In the above output, the userid is float.
#
# The reason is in python string > float > int > bool.
#
# If a collection of data have int, float value, then final type of the collection of data will be float.
#
# Here usreid have int,NaN and NaN is a float so all vaules will br float in userid

# %% [markdown]
# #pandas merging
#
# There are 4 types of merging
#
# inner
#
# left
#
# right
#
# outer

# %%
print(users)
print(msgs)
# Out:
#    userid     name
# 0       1   sharad
# 1       2   shahid
# 2       3  khusali
#    userid        msg
# 0       1        hmm
# 1       1      achha
# 2       2  theek hai
# 3       4       nice

# %%
users.merge(msgs) #by default inner merge, its same as sql inner join
# Out:
#    userid    name        msg
# 0       1  sharad        hmm
# 1       1  sharad      achha
# 2       2  shahid  theek hai

# %%
users.merge(msgs, on = 'userid') #join on userid
# Out:
#    userid    name        msg
# 0       1  sharad        hmm
# 1       1  sharad      achha
# 2       2  shahid  theek hai

# %%
#left join
print(users)
print(msgs)
# Out:
#    userid     name
# 0       1   sharad
# 1       2   shahid
# 2       3  khusali
#    userid        msg
# 0       1        hmm
# 1       1      achha
# 2       2  theek hai
# 3       4       nice

# %%
#left join
users.merge(msgs, on='userid', how = 'left') #its same as sql left join
# Out:
#    userid     name        msg
# 0       1   sharad        hmm
# 1       1   sharad      achha
# 2       2   shahid  theek hai
# 3       3  khusali        NaN

# %%
#right join
users.merge(msgs, on='userid', how = 'right') #its same as sql right join
# Out:
#    userid    name        msg
# 0       1  sharad        hmm
# 1       1  sharad      achha
# 2       2  shahid  theek hai
# 3       4     NaN       nice

# %%
#full/outer join
users.merge(msgs, on='userid', how = 'outer') #its same as sql outer join
# Out:
#    userid     name        msg
# 0       1   sharad        hmm
# 1       1   sharad      achha
# 2       2   shahid  theek hai
# 3       3  khusali        NaN
# 4       4      NaN       nice

# %%
#how to merge in case of no common col index
#i.e. there are no same column exist in 2 df
users.rename(columns = {'userid':'id'}, inplace=True)
users
# Out:
#    id     name
# 0   1   sharad
# 1   2   shahid
# 2   3  khusali

# %%
users.merge(msgs, left_on = 'id', right_on= 'userid', how='left') #here users is left and msgs is right
# Out:
#    id     name  userid        msg
# 0   1   sharad     1.0        hmm
# 1   1   sharad     1.0      achha
# 2   2   shahid     2.0  theek hai
# 3   3  khusali     NaN        NaN

# %% [markdown]
# #IMDB Movies

# %% [markdown]
# Let's download and read the IMDB dataset -
#
# - File1: https://drive.google.com/file/d/1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd/view?usp=sharing
# - File2: https://drive.google.com/file/d/1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm/view?usp=sharing

# %%
# !gdown 1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1s2TkjSpzNc4SyxqRrQleZyDIHlc7bxnd
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 78.5MB/s]

# %%
# !gdown 1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Ws-_s1fHZ9nHfGLVUQurbHDvStePlEJm
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 85.5MB/s]

# %%
movies = pd.read_csv('movies.csv')
directors = pd.read_csv('directors.csv')

# %%
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# ...

# %%
directors.head()
# Out:
#    Unnamed: 0      director_name    id gender
# 0           0      James Cameron  4762   Male
# 1           1     Gore Verbinski  4763   Male
# 2           2         Sam Mendes  4764   Male
# 3           3  Christopher Nolan  4765   Male
# 4           4     Andrew Stanton  4766   Male

# %%
#here 'unamed' columns can be considerd as index
movies = pd.read_csv('movies.csv', index_col = 0)
directors = pd.read_csv('directors.csv', index_col = 0)

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
#shape
movies.shape
# Out:
# (1465, 11)

# %%
directors.shape
# Out:
# (2349, 3)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1465 entries, 0 to 4768
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1465 non-null   int64
#  1   budget        1465 non-null   int64
#  2   popularity    1465 non-null   int64
#  3   revenue       1465 non-null   int64
#  4   title         1465 non-null   object
#  5   vote_average  1465 non-null   float64
#  6   vote_count    1465 non-null   int64
#  7   director_id   1465 non-null   int64
#  8   year          1465 non-null   int64
#  9   month         1465 non-null   object
#  10  day           1465 non-null   object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 137.3+ KB

# %%
#no of directors in movies df
movies['director_id'].unique()
# Out:
# array([4762, 4763, 4764, 4765, 4767, 4771, 4772, 4773, 4774, 4775, 4776,
#        4777, 4779, 4780, 4782, 4785, 4786, 4788, 4791, 4793, 4794, 4797,
#        4798, 4799, 4802, 4803, 4804, 4805, 4808, 4809, 4810, 4811, 4812,
#        4813, 4814, 4829, 4831, 4832, 4833, 4838, 4839, 4842, 4845, 4846,
#        4847, 4849, 4854, 4857, 4858, 4859, 4863, 4865, 4866, 4867, 4868,
#        4872, 4873, 4874, 4876, 4880, 4881, 4885, 4886, 4888, 4889, 4890,
#        4892, 4893, 4894, 4900, 4904, 4909, 4913, 4915, 4917, 4918, 4921,
#        4923, 4924, 4925, 4926, 4927, 4930, 4935, 4936, 4945, 4947, 4948,
#        4949, 4955, 4958, 4960, 4964, 4965, 4967, 4974, 4978, 4989, 4991,
#        4993, 4995, 4998, 5002, 5005, 5008, 5009, 5014, 5017, 5024, 5031,
#        5033, 5034, 5035, 5037, 5039, 5047, 5053, 5056, 5059, 5061, 5067,
#        5082, 5087, 5088, 5093, 5096, 5097, 5101, 5105, 5111, 5113, 5115,
#        5116, 5123, 5125, 5130, 5132, 5135, 5140, 5147, 5148, 5152, 5157,
# ...

# %%
movies['director_id'].nunique()
# Out:
# 199

# %%
movies.shape
# Out:
# (1465, 11)

# %%
movies['title'].nunique()
# Out:
# 1465

# %%
movies['director_id']
# Out:
# 0       4762
# 1       4763
# 2       4764
# 3       4765
# 4       4767
#         ...
# 1460    4809
# 1461    5369
# 1462    5148
# 1463    5535
# 1464    5097
# Name: director_id, Length: 1465, dtype: int64

# %%
'sun' in  'sunku' #works on scalar not vector
# Out:
# True

# %%
directors['id']
# Out:
# 0       4762
# 1       4763
# 2       4764
# 3       4765
# 4       4766
#         ...
# 2344    7106
# 2345    7107
# 2346    7108
# 2347    7109
# 2348    7110
# Name: id, Length: 2349, dtype: int64

# %%
movies['director_id'].isin(directors['id'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1460    True
# 1461    True
# 1462    True
# 1463    True
# 1464    True
# Name: director_id, Length: 1465, dtype: bool

# %%
#all and any example
a = [True, True,True]
b = [True, True,False]
print('a :- ', a)
print('a all :- ',np.all(a))
print('a any :- ',np.any(a))

print('b :- ', b)
print('b all :- ',np.all(b))
print('b any :- ',np.any(b))
# Out:
# a :-  [True, True, True]
# a all :-  True
# a any :-  True
# b :-  [True, True, False]
# b all :-  False
# b any :-  True

# %%
#check any values is false, or if all value are true
np.all(movies['director_id'].isin(directors['id']))
# Out:
# True

# %%
np.all(movies['director_id'].isin(directors['id'])).all()
# Out:
# True

# %% [markdown]
# #merging movies and directors

# %%
pd.concat([movies,directors])
# Out:
#          id       budget  popularity       revenue  \
# 0     43597  237000000.0       150.0  2.787965e+09
# 1     43598  300000000.0       139.0  9.610000e+08
# 2     43599  245000000.0       107.0  8.806746e+08
# 3     43600  250000000.0       112.0  1.084939e+09
# 5     43602  258000000.0       115.0  8.908716e+08
# ...     ...          ...         ...           ...
# 2344   7106          NaN         NaN           NaN
# 2345   7107          NaN         NaN           NaN
# 2346   7108          NaN         NaN           NaN
# 2347   7109          NaN         NaN           NaN
# 2348   7110          NaN         NaN           NaN
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2     11800.0
# 1     Pirates of the Caribbean: At World's End           6.9      4500.0
# 2                                      Spectre           6.3      4466.0
# ...

# %%
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
              #left df  #right df
data = pd.merge(movies, directors, left_on='director_id', right_on='id', how='left')
data
#note:- duplicate cols are suffixed by _x(for left df) and _y(for right df)
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data.drop(columns =['id_y', 'director_id'], inplace=True)

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
data.rename({'id_x':'id'}, axis=1,inplace=True)

# %%
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %% [markdown]
# ### Post-read
#
# - [IMDB data exploration](https://colab.research.google.com/drive/1yrfHSQYUMxxLKGUG-gCPf-R232BuimiR?usp=sharing)
#
# From here, we have the opportunity to delve into various aspects of the data, such as:
#
# - Converting the revenue values into Millions of USD.
# - Identifying the Top 5 most popular movies.
#
# ... and so on.

# %% [markdown]
# #apply()

# %%
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
#convert male to 0 and feamle 1, this is called label encoding
#here data is the 'gender' series
def encode(data):
  if data == 'Male':
    return 0
  else:
    return 1

# %%
data['gender'].apply(encode)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1460    0
# 1461    0
# 1462    0
# 1463    0
# 1464    1
# Name: gender, Length: 1465, dtype: int64

# %%
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# ...

# %%
data['gender']= data['gender'].apply(encode)
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender
# 0   Dec  Thursday      James Cameron       0
# 1   May  Saturday     Gore Verbinski       0
# 2   Oct    Monday         Sam Mendes       0
# 3   Jul    Monday  Christopher Nolan       0
# ...

# %%
#sum of revenue of all movies and sum of budget of all movies
#here the parameter passed to np.sum is df ['revenue','budget']
data[['revenue', 'budget']].apply(np.sum)
# Out:
# revenue    209866997305
# budget      70353617179
# dtype: int64

# %%
pd.sum? #no sum in pandas
# Out:
#   File "<ipython-input-57-2413fab1ebfe>", line 1
#     pd.sum? #no sum in pandas
#           ^
# SyntaxError: invalid syntax

# %%
#sum of revenue + budget
data[['revenue', 'budget']].apply(np.sum, axis=1)
# Out:
# 0       3024965087
# 1       1261000000
# 2       1125674609
# 3       1334939099
# 4       1148871626
#            ...
# 1460        321952
# 1461       3178130
# 1462             0
# 1463             0
# 1464       2260920
# Length: 1465, dtype: int64

# %%
data[['revenue', 'budget']].head(3)
# Out:
#       revenue     budget
# 0  2787965087  237000000
# 1   961000000  300000000
# 2   880674609  245000000

# %%
#profit for each movie
#here the parameter(x) passed to profit is df ['revenue', 'budget']
def profit(x):
  return x['revenue'] - x['budget']

data[['revenue', 'budget']].apply(profit, axis=1)
# Out:
# 0       2550965087
# 1        661000000
# 2        635674609
# 3        834939099
# 4        632871626
#            ...
# 1460        321952
# 1461       3124130
# 1462             0
# 1463             0
# 1464       1820920
# Length: 1465, dtype: int64

# %%
#this will error, by default operation is performed on row and in row there no revenue or budget
data[['revenue', 'budget']].apply(profit)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-22555648a3a7> in <cell line: 2>()
#       1 #this will error, by default operation is performed on row and in row there no revenue or budget
# ----> 2 data[['revenue', 'budget']].apply(profit)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9421             kwargs=kwargs,
#    9422         )
# -> 9423         return op.apply().__finalize__(self, method="apply")
#    9424
#    9425     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     676             return self.apply_raw()
#     677
# --> 678         return self.apply_standard()
#     679
#     680     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#     796
# ...

# %%
#adding new column
data['profit'] = data[['revenue', 'budget']].apply(profit, axis=1)
data.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name  gender      profit
# 0   Dec  Thursday      James Cameron       0  2550965087
# 1   May  Saturday     Gore Verbinski       0   661000000
# 2   Oct    Monday         Sam Mendes       0   635674609
# ...

# %% [markdown]
# #group by

# %%
data.groupby('director_name')

# %%
# number of groups, it will be same as unique director count
data.groupby('director_name').ngroups
# Out:
# 199

# %%
data.groupby('director_name').groups
#In output Adam Mckay is group name and [176, 323, 366, 505, 839, 916] are indexes(these are grouped).
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 
# ...

# %%
data.groupby('director_name').get_group('Christopher Nolan')
# Out:
#          id     budget  popularity     revenue                  title  \
# 3     43600  250000000         112  1084939099  The Dark Knight Rises
# 45    43662  185000000         187  1004558444        The Dark Knight
# 58    43692  165000000         724   675120017           Interstellar
# 59    43693  160000000         167   825532764              Inception
# 74    43716  150000000         115   374218673          Batman Begins
# 565   44630   46000000          41   113714830               Insomnia
# 641   44793   40000000          74   109676311           The Prestige
# 1341  47170    9000000          60    39723096                Memento
#
#       vote_average  vote_count  year month        day      director_name  \
# 3              7.6        9106  2012   Jul     Monday  Christopher Nolan
# 45             8.2       12002  2008   Jul  Wednesday  Christopher Nolan
# 58             8.1       10867  2014   Nov  Wednesday  Christopher Nolan
# ...

# %%
#get count of movies of each director
data.groupby('director_name')['title'].count()
#how to remember this :) :)
# Out:
# director_name
# Adam McKay                      6
# Adam Shankman                   8
# Alejandro González Iñárritu     6
# Alex Proyas                     5
# Alexander Payne                 5
#                                ..
# Wes Craven                     10
# Wolfgang Petersen               7
# Woody Allen                    18
# Zack Snyder                     7
# Zhang Yimou                     6
# Name: title, Length: 199, dtype: int64

# %%
# getting first and last year of director (applying more than one function i.e. min and max)
result = data.groupby('director_name')['year'].aggregate(['min','max'])
result
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
result.reset_index()
# Out:
#                    director_name   min   max
# 0                     Adam McKay  2004  2015
# 1                  Adam Shankman  2001  2012
# 2    Alejandro González Iñárritu  2000  2015
# 3                    Alex Proyas  1994  2016
# 4                Alexander Payne  1999  2013
# ..                           ...   ...   ...
# 194                   Wes Craven  1984  2011
# 195            Wolfgang Petersen  1981  2006
# 196                  Woody Allen  1977  2013
# 197                  Zack Snyder  2004  2016
# 198                  Zhang Yimou  2002  2014
#
# [199 rows x 3 columns]

# %%
#groupby of more than 1 col
result = data.groupby(by =['director_name', 'year'])
result

# %% [markdown]
# #Assignment Q1

# %%
#note: following code is not from assignement q1, it is just explanation for 'apply' function
#explanation about apply function
#One thing to remember is the variable in the apply function is the df or series.

# %%
#Applying a function along an axis:
#In this example, we'll compute the sum along each column (axis=0) and the sum along each row (axis=1) of a DataFrame.

import pandas as pd

# Create a sample DataFrame
data = {'A': [1, 2, 3],
        'B': [4, 5, 6],
        'C': [7, 8, 9]}
df = pd.DataFrame(data)

# Apply a function along columns (axis=0)
sum_columns = df.apply(sum, axis=0)
print("Sum along columns:")
print(sum_columns)

# Apply a function along rows (axis=1)
sum_rows = df.apply(sum, axis=1)
print("\nSum along rows:")
print(sum_rows)
# Out:
# Sum along columns:
# A     6
# B    15
# C    24
# dtype: int64
#
# Sum along rows:
# 0    12
# 1    15
# 2    18
# dtype: int64

# %%
#Applying a function to each element:
#In this example, we'll square each element of a DataFrame using the applymap() function.

def sq(x):
  return x*x;

# Square each element of the DataFrame
squared_df = df.applymap(sq)
#squared_df = df.applymap(lambda x: x**2) #we do operation on each element using lambda function, need to explore about it.
print("Squared DataFrame:")
print(squared_df)
# Out:
# Squared DataFrame:
#    A   B   C
# 0  1  16  49
# 1  4  25  64
# 2  9  36  81

# %%
#Applying a function to a single axis:
#In this example, we'll compute the square root of each element in column 'A' of the DataFrame.

# Compute the square root of each element in column 'A'
sqrt_column_A = df['A'].apply(lambda x: x**0.5)
print("Square root of column 'A':")
print(sqrt_column_A)
# Out:
# Square root of column 'A':
# 0    1.000000
# 1    1.414214
# 2    1.732051
# Name: A, dtype: float64

# %%
#actual assignment q1 start here
import pandas as pd
import numpy as np

# Create a sample DataFrame
data = {'A': [1, 2, 3, np.nan,5],
        'B': [4, 5, 6, np.nan, np.nan],
        'C': [7, 8, 9, np.nan,5]}
df = pd.DataFrame(data)
df
# Out:
#      A    B    C
# 0  1.0  4.0  7.0
# 1  2.0  5.0  8.0
# 2  3.0  6.0  9.0
# 3  NaN  NaN  NaN
# 4  5.0  NaN  5.0

# %%
def is_null(x):
   return sum(x.isnull())
df.apply(is_null, axis=1)
# Out:
# 0    0
# 1    0
# 2    0
# 3    3
# 4    1
# dtype: int64

# %% [markdown]
# #assignment Q2

# %%
import pandas as pd

data = {
    'name': ['Elon', 'Jeff', 'Bill', 'Falguni'],
    'gender': ['M', 'F', 'M', 'F'],
    'income': [53000.0, 28000.0, 25000.0, 44000.0]
}

df = pd.DataFrame(data)

# %%
result = df.groupby('gender')
print(result)

# %%
result = df.groupby('gender')['income']
print(result)

# %%
result = df.groupby('gender')['income'].aggregate(['mean'])
result
# Out:
#            mean
# gender
# F       36000.0
# M       39000.0

# %%
result.rename(columns ={'mean':'income'},inplace=True)
result
# Out:
#          income
# gender
# F       36000.0
# M       39000.0

# %%
result.reset_index()
# Out:
#   gender   income
# 0      F  36000.0
# 1      M  39000.0

# %%
#note: able to get output in colab but not in dashboard

# %% [markdown]
# #assignment Q3

# %%
import pandas as pd

data = {
    'roll_no': [1, 2, 1, 3, 1, 3, 3, 3, 2, 2, 1, 2],
    'subject': ['NN', 'DL', 'ML', 'Prob', 'DL', 'ML', 'DL', 'NN', 'NN', 'Prob', 'Prob', 'ML'],
    'marks': [97, 63, 63, 71, 64, 90, 66, 46, 74, 62, 94, 67]
}

df = pd.DataFrame(data)
df
# Out:
#     roll_no subject  marks
# 0         1      NN     97
# 1         2      DL     63
# 2         1      ML     63
# 3         3    Prob     71
# 4         1      DL     64
# 5         3      ML     90
# 6         3      DL     66
# 7         3      NN     46
# 8         2      NN     74
# 9         2    Prob     62
# 10        1    Prob     94
# 11        2      ML     67

# %%
df.groupby(by = 'subject')['marks'].max()
# Out:
# subject
# DL      66
# ML      90
# NN      97
# Prob    94
# Name: marks, dtype: int64

# %%
df.groupby(by = 'subject')['marks'].aggregate(max)
# Out:
# subject
# DL      66
# ML      90
# NN      97
# Prob    94
# Name: marks, dtype: int64

# %%
df.groupby(by = 'subject')['marks'].idxmax()
# Out:
# subject
# DL       6
# ML       5
# NN       0
# Prob    10
# Name: marks, dtype: int64

# %%
result = df.loc[df.groupby(by = 'subject')['marks'].idxmax()][['subject','marks','roll_no']]
result
# Out:
#    subject  marks  roll_no
# 6       DL     66        3
# 5       ML     90        3
# 0       NN     97        1
# 10    Prob     94        1

# %%
result = result.reset_index()
result
# Out:
#    index subject  marks  roll_no
# 0      6      DL     66        3
# 1      5      ML     90        3
# 2      0      NN     97        1
# 3     10    Prob     94        1

# %%
result.drop('index', axis=1)
# Out:
#   subject  marks  roll_no
# 0      DL     66        3
# 1      ML     90        3
# 2      NN     97        1
# 3    Prob     94        1

# %%
#another method using groupby and merge. this failing on dashboard. check later
df
# Out:
#     roll_no subject  marks
# 0         1      NN     97
# 1         2      DL     63
# 2         1      ML     63
# 3         3    Prob     71
# 4         1      DL     64
# 5         3      ML     90
# 6         3      DL     66
# 7         3      NN     46
# 8         2      NN     74
# 9         2    Prob     62
# 10        1    Prob     94
# 11        2      ML     67

# %%
max_marks = df.groupby('subject')['marks'].max()
max_marks
# Out:
# subject
# DL      66
# ML      90
# NN      97
# Prob    94
# Name: marks, dtype: int64

# %%
max_marks = max_marks.reset_index()
max_marks
# Out:
#   subject  marks
# 0      DL     66
# 1      ML     90
# 2      NN     97
# 3    Prob     94

# %%
max_marks = max_marks.drop('subject', axis=1)
max_marks
# Out:
#    marks
# 0     66
# 1     90
# 2     97
# 3     94

# %%
result = pd.merge(df,max_marks, on = 'marks')
result
# Out:
#    roll_no subject  marks
# 0        1      NN     97
# 1        3      ML     90
# 2        3      DL     66
# 3        1    Prob     94

# %%
result = result.sort_values('subject')
result
# Out:
#    roll_no subject  marks
# 2        3      DL     66
# 1        3      ML     90
# 0        1      NN     97
# 3        1    Prob     94

# %%
result = result.reset_index()
result
# Out:
#    index  roll_no subject  marks
# 0      2        3      DL     66
# 1      1        3      ML     90
# 2      0        1      NN     97
# 3      3        1    Prob     94

# %%
result = result.drop('index', axis=1)
result
# Out:
#    roll_no subject  marks
# 0        3      DL     66
# 1        3      ML     90
# 2        1      NN     97
# 3        1    Prob     94

# %%
#change order of cols
result = result[['subject', 'marks','roll_no']]
result
# Out:
#   subject  marks  roll_no
# 0      DL     66        3
# 1      ML     90        3
# 2      NN     97        1
# 3    Prob     94        1

# %%
#another method
result = df.groupby(by = 'subject').aggregate(max)
result
# Out:
#          roll_no  marks
# subject
# DL             3     66
# ML             3     90
# NN             3     97
# Prob           3     94

# %%
result = result.reset_index()
result
# Out:
#   subject  roll_no  marks
# 0      DL        3     66
# 1      ML        3     90
# 2      NN        3     97
# 3    Prob        3     94

# %%
#change col order
result = result[['subject', 'marks', 'roll_no']]
result
# Out:
#   subject  marks  roll_no
# 0      DL     66        3
# 1      ML     90        3
# 2      NN     97        3
# 3    Prob     94        3

# %% [markdown]
# #assignment Q4

# %%
import pandas as pd

data = {'name':["Ram","Shyam","Mukesh","Suresh"],'age':[10,18,60,50]}


df = pd.DataFrame(data)
df
# Out:
#      name  age
# 0     Ram   10
# 1   Shyam   18
# 2  Mukesh   60
# 3  Suresh   50

# %%
def age1(x):
  if(x<18):
    x ='kid'
  elif(x<=50):
    x= 'adult'
  else:
    x='senior'
  return x

df['age'] = df['age'].apply(age1)

df
# Out:
#      name     age
# 0     Ram     kid
# 1   Shyam   adult
# 2  Mukesh  senior
# 3  Suresh   adult

# %% [markdown]
# #assignemnt Q5

# %%
import pandas as pd

data = {
    'name': ['Jim', 'Clarke', 'Kent', 'Mark'],
    'username': ['itsjimhere', 'clark002', 'itskentment', 'markyoumustknow'],
    'userid': [20, 10, 86, 21]
}

df = pd.DataFrame(data)
df
# Out:
#      name         username  userid
# 0     Jim       itsjimhere      20
# 1  Clarke         clark002      10
# 2    Kent      itskentment      86
# 3    Mark  markyoumustknow      21

# %%
df.columns
# Out:
# Index(['name', 'username', 'userid'], dtype='object')

# %%
def check(name,username):
    return name.lower() in username


df[~(df.apply(lambda x:check(x['name'],x['username']), axis=1))]['userid']
# Out:
# 1    10
# Name: userid, dtype: int64

# %%
#another method to solve the question
def check1(x):
    return x['name'].lower() in x['username']
    #print(x)


#df.apply(lambda x: check(x['name'], x['username']), axis=1)
df.apply(check1, axis=1)
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
# info apply function
# if axis = 0 then col are passed and we accsess it like ['name']
# if axis = 1 then row are passed and we accsess it like ['name']
import pandas as pd

data = {
    'name': ['Jim', 'Clarke', 'Kent', 'Mark'],
    'username': ['itsjimhere', 'clark002', 'itskentment', 'markyoumustknow'],
    'userid': [20, 10, 86, 21]
}


def print_row(x):
    print(x)


df.apply(print_row, axis=1)
# Out:
# name               Jim
# username    itsjimhere
# userid              20
# Name: 0, dtype: object
# name          Clarke
# username    clark002
# userid            10
# Name: 1, dtype: object
# name               Kent
# username    itskentment
# userid               86
# Name: 2, dtype: object
# name                   Mark
# username    markyoumustknow
# userid                   21
# Name: 3, dtype: object
# 0    None
# 1    None
# 2    None
# 3    None
# dtype: object

# %%
# info apply function
# if axis = 0 then col are passed and we accsess it like ['name']
# if axis = 1 then row are passed and we accsess it like ['name']
import pandas as pd

data = {
    'name': ['Jim', 'Clarke', 'Kent', 'Mark'],
    'username': ['itsjimhere', 'clark002', 'itskentment', 'markyoumustknow'],
    'userid': [20, 10, 86, 21]
}


def print_row(x):
    print(x)


df.apply(print_row, axis=0)
# Out:
# 0       Jim
# 1    Clarke
# 2      Kent
# 3      Mark
# Name: name, dtype: object
# 0         itsjimhere
# 1           clark002
# 2        itskentment
# 3    markyoumustknow
# Name: username, dtype: object
# 0    20
# 1    10
# 2    86
# 3    21
# Name: userid, dtype: int64
# name        None
# username    None
# userid      None
# dtype: object

# %% [markdown]
# #assignment Q6

# %%
import pandas as pd

data = {
    'name': ['Luffy', 'Chopper', 'Zoro', 'Sanji'],
    'marks': [15, 89, 33, 32]
}

df = pd.DataFrame(data)
df
# Out:
#       name  marks
# 0    Luffy     15
# 1  Chopper     89
# 2     Zoro     33
# 3    Sanji     32

# %%
k = 32
df['marks']>k
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: marks, dtype: bool

# %%
df[df['marks']>k].drop('marks', axis=1)['name']
# Out:
# 1    Chopper
# 2       Zoro
# Name: name, dtype: object

# %% [markdown]
# #assignment Q7

# %% [markdown]
# In Pandas, the isin() function is used to filter data based on whether values are present in a specified list, Series, DataFrame, or dictionary. It returns a boolean Series indicating whether each element of the DataFrame is contained in the specified values.

# %%
import pandas as pd

data = {
    'cust_id': [101, 102, 103, 104],
    'name': ['rick', 'morty', 'pickle', 'jerry'],
}

df = pd.DataFrame(data)
df
# Out:
#    cust_id    name
# 0      101    rick
# 1      102   morty
# 2      103  pickle
# 3      104   jerry

# %%
df.isin([101, 102, 120])
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2    False  False
# 3    False  False

# %%
df.isin({'cust_id': [101, 102]})
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2    False  False
# 3    False  False

# %%
df.isin(df.cust_id)
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2     True  False
# 3     True  False

# %%
df.name.isin('rick')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-f9a643cbc56e> in <cell line: 1>()
# ----> 1 df.name.isin('rick')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in isin(self, values)
#    5404         dtype: bool
#    5405         """
# -> 5406         result = algorithms.isin(self._values, values)
#    5407         return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5408             self, method="isin"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in isin(comps, values)
#     461         )
#     462     if not is_list_like(values):
# --> 463         raise TypeError(
#     464             "only list-like objects are allowed to be passed "
#     465             f"to isin(), you passed a [{type(values).__name__}]"
#
# ...
