# %% [markdown]
# <a href="https://colab.research.google.com/github/shivraj7/scalar/blob/main/L3_ML_LR2_PostRead_NormalEquation_part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# By equating the values of X and Y, we can compute the values of W

# %% [markdown]
# ## Comparing Normal equation to GD
# - There is no need to for feature scaling in Normal Equation
# - GD works well for any number of dimensions.
# - But, We need to calculate $(X^TX)^{-1}$ in normal equation
#   - If d is large, then closed form solution is not recommended.
